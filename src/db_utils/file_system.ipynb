# %%
display(dbutils.fs.ls("/Volumes/workspace/default/vol1"))

# %%
df = spark.read.csv("/Volumes/workspace/default/vol1/employee.csv", header=True, inferSchema=True)
display(df)

# %%
display(df)

# %%
display(dbutils.fs.ls("/"))

# %%
dbutils.help()

# %%
dbutils.fs.head( "/Volumes/workspace/default/vol1/employee.csv")

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/vol1/csv")

# %%
dbutils.fs.cp("/Volumes/workspace/default/vol1/employee.csv","/Volumes/workspace/default/vol1/csv")

# %%
dbutils.fs.rm("/Volumes/workspace/default/vol1/csv/employee.csv", True)
