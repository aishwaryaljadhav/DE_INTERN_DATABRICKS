# %%
df = spark.read.csv(
    "/Volumes/workspace/default/vol1/employee.csv",
    header=True,
    inferSchema=True
)

df.show()

# %%
df.printSchema()

df_selected = df.select("id", "name")

df_filtered = df.filter(df["id"] > 10)

display(df_filtered)
