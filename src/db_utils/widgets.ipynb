# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("input_cust_id", "10000", "Customer_ID")

# %%
dbutils.widgets.get("input_cust_id")

# %%
dbutils.widgets.dropdown("input_cust_id", "10000", ["10000", "10001", "10002"], "Customer_ID")

# %%
dbutils.widgets.combobox("input_cust_id", "10000", ["10000", "10001", "10002"], "Customer_ID")

# %%
dbutils.widgets.getAll()

# %%
dbutils.widgets.multiselect("input_cust_id", "10000", ["10000", "10001", "10002"], "Customer_ID")

# %%
dbutils.widgets.remove("input_cust_id")
